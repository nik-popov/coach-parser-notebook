# %% [markdown]
# <a href="https://colab.research.google.com/github/nik-popov/coach-parser-notebook/blob/main/coach_parser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import re
from urllib.parse import urljoin
def parse_product_tiles(html_content, base_url="https://www.coach.com"):
    """Parse HTML content to extract product information, including thumbnail URL.

    Args:
        html_content (str): HTML content to parse.
        base_url (str): Base URL for resolving relative image URLs.

    Returns:
        list: List of dictionaries containing product details.
    """
    soup = BeautifulSoup(html_content, 'html.parser')
    product_tiles = soup.find_all('div', class_=re.compile('product-tile.*'))
    products = []

    for tile in product_tiles:
        product = {}

        # Extract product name
        name_elem = tile.find('p', class_='chakra-text css-as1hzn')
        product['name'] = name_elem.text.strip() if name_elem else ' '

        # Extract product URL
        link_elem = tile.find('a', class_='css-avqw6d')
        href = link_elem.get('href') if link_elem else None
        if href:
            product['product_url'] = urljoin(base_url, href)
        else:
            product['product_url'] = ' '

        # Extract item_id from class (e.g., product-tile-CV933 -> CV933)
        class_list = tile.get('class', [])
        item_id_match = next((cls.split('product-tile-')[1] for cls in class_list if cls.startswith('product-tile-') and len(cls.split('-')) > 2), None)
        product['item_id'] = item_id_match if item_id_match else ' '

        # Extract variation_id from frp in URL (e.g., frp=CV933+IMXAQ -> IMXAQ)
        variation_id = ' '
        if href:
            frp_match = re.search(r'frp=([^+]+)\+([^&]+)', href)
            if frp_match:
                variation_id = frp_match.group(2)
        product['variation_id'] = variation_id

        # Extract comparable value (original price)
        comparable_elem = tile.find('span', {'data-qa': 'txt_comparable_value_price'})
        comparable_value = comparable_elem.text.strip() if comparable_elem else ' '
        product['comparable_value'] = comparable_value

        # Extract sale price
        sale_price_elem = tile.find('span', class_=re.compile('salesPrice.*'))
        sale_price = sale_price_elem.text.strip() if sale_price_elem else ' '
        product['sale_price'] = sale_price

        # Calculate discount percentage if comparable and sale prices are available
        discount_percentage = ' '
        if comparable_value != ' ' and sale_price != ' ':
            try:
                comp_val = float(re.sub(r'[^\d.]', '', comparable_value))
                sale_val = float(re.sub(r'[^\d.]', '', sale_price))
                if comp_val > 0:
                    discount = ((comp_val - sale_val) / comp_val) * 100
                    discount_percentage = f"{int(round(discount))}%"
            except ValueError:
                pass
        product['discount_percentage'] = discount_percentage

        # Extract additional discount (not present in sample, keep for compatibility)
        additional_discount_elem = tile.find('span', class_='plpprimarytag wk47memorialday')
        product['additional_discount'] = additional_discount_elem.text.strip() if additional_discount_elem else ' '

        # Extract thumbnail URL (primary product image)
        thumbnail_div = tile.find('div', class_='product-thumbnail plpv3 css-1gasjii')
        img_tag = thumbnail_div.find('img', class_='chakra-image css-klg1v') if thumbnail_div else None
        if img_tag and img_tag.get('src'):
            img_url = img_tag['src']
            if not img_url.startswith(('http://', 'https://')):
                img_url = urljoin(base_url, img_url)
            product['image_url'] = img_url
        else:
            product['image_url'] = ' '

        # Extract description (not typically present in tile; placeholder or extract alt text as fallback)
        description = ' '
        if img_tag and img_tag.get('alt'):
            alt_text = img_tag['alt']
            # Extract potential description from alt, e.g., after the name
            if product['name'] in alt_text:
                description = alt_text.split(product['name'], 1)[-1].strip(',').strip()
        product['description'] = description

        products.append(product)

    return products


def print_product_info(products):
    for product in products:
        print(f"Product: {product['name']}")
        print(f"Item ID: {product['item_id']}")
        print(f"Variation ID: {product['variation_id']}")
        print(f"Product URL: {product['product_url']}")
        print(f"Comparable Value: {product['comparable_value']}")
        print(f"Sale Price: {product['sale_price']}")
        print(f"Discount: {product['discount_percentage']}")
        print(f"Additional Discount: {product['additional_discount']}")
        print(f"Description: {product['description']}")
        print("-" * 50)
def load_html_from_txt(file_path):
    """Load HTML content from a text file.

    Args:
        file_path (str): Path to the text file containing HTML content.

    Returns:
        str: HTML content as a string, or None if an error occurs.

    Raises:
        FileNotFoundError: If the specified file does not exist.
        IOError: If there's an error reading the file.
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            html_content = file.read()
        return html_content
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return None
    except IOError as e:
        print(f"Error reading file: {e}")
        return None
import csv

def save_to_csv(products, csv_file_path):
    """Save product information to a CSV file.

    Args:
        products (list): List of dictionaries containing product details.
        csv_file_path (str): Path to the output CSV file.

    Returns:
        bool: True if saving was successful, False otherwise.
    """
    try:
        with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
            fieldnames = [
                'Name', 'Item_ID', 'Variation_ID', 'Product_URL', 'Comparable_Value',
                'Sale_Price', 'Discount_Percentage', 'Additional_Discount',
                'Image_URL', 'Description'
            ]
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

            writer.writeheader()
            for product in products:
                writer.writerow({
                    'Name': product.get('name', ' '),
                    'Item_ID': product.get('item_id', ' '),
                    'Variation_ID': product.get('variation_id', ' '),
                    'Product_URL': product.get('product_url', ' '),
                    'Comparable_Value': product.get('comparable_value', ' '),
                    'Sale_Price': product.get('sale_price', ' '),
                    'Discount_Percentage': product.get('discount_percentage', ' '),
                    'Additional_Discount': product.get('additional_discount', ' '),
                    'Image_URL': product.get('image_url', ' '),
                    'Description': product.get('description', ' ')
                })
        print(f"Data successfully saved to {csv_file_path}")
        return True
    except IOError as e:
        print(f"Error writing to CSV file: {e}")
        return False

# %%
if __name__ == "__main__":
    # Path to your text file containing HTML
    input_file_path = "/content/coach-category.txt"

    output_csv_path = "coach_outlet_bags_8-5-25.csv"

    # Load HTML content from text file
    html_content = load_html_from_txt(input_file_path)

    if html_content:
        # Parse product tiles
        products = parse_product_tiles(html_content)

        if products:
            # Save to CSV
            save_to_csv(products, output_csv_path)

            # Optional: Print product info for verification
            print_product_info(products)
        else:
            print("No products found in the HTML content.")
# Out:
# Data successfully saved to coach_outlet_bags_8-5-25.csv
# Product: Teri Shoulder Bag In Signature Canvas
# Item ID: CV933
# Variation ID: IMXAQ
# Product URL: https://www.coach.com/products/teri-shoulder-bag-in-signature-canvas/CV933.html?frp=CV933+IMXAQ
# Comparable Value:
# Sale Price: $219
# Discount:
# Additional Discount:
# Description: Shoulder Bag,Metal,Tag Embellishment,Logo,Embossed,Casual,Brown,Front View
# --------------------------------------------------
# Product: City Tote Bag In Signature Canvas
# Item ID: CV976
# Variation ID: IMXDM
# Product URL: https://www.coach.com/products/city-tote-bag-in-signature-canvas/CV976.html?frp=CV976+IMXDM
# Comparable Value: $398
# Sale Price: $149   - Sales Price    - Original Price
# Discount: 63%
# Additional Discount:
# Description: Tote,Color Block,Embossed,Piping,Metal,Tag Embellishment,Logo,Casual,Beige,Front View
# --------------------------------------------------
# Product: Laurel Shoulder Bag
# Item ID: CR148
# Variation ID: IMBLK
# Product URL: https://www.coach.com/products/laurel-shoulder-bag/CR148.html?frp=CR148+IMBLK
# Comparable Value: $428
# Sale Price: $219   - Sales Price    - Original Price
# Discount: 49%
# Additional Discount:
# Description: Leather,Hobo,Logo,Gold Metal,Casual,Black,Front View
# --------------------------------------------------
# Product: Nolita 19 In Signature Canvas
# Item ID: CW426
# Variation ID: IMXDM
# Product URL: https://www.coach.com/products/nolita-19-in-signature-canvas/CW426.html?frp=CW426+IMXDM
# Comparable Value: $188
# Sale Price: $119   - Sales Price    - Original Price
# Discount: 37%
# Additional Discount:
# Description: Canvas,Shoulder Bag,Metal,Piping,Logo,Tag Embellishment,Casual,Beige,Front View
# --------------------------------------------------
# Product:
# Item ID:
# Variation ID:
# Product URL:
# Comparable Value:
# Sale Price:
# Discount:
# Additional Discount:
# Description:
# --------------------------------------------------
# Product: Mini Klare Crossbody Bag In Signature Canvas
# Item ID: CW206
# Variation ID: IMXAQ
# Product URL: https://www.coach.com/products/mini-klare-crossbody-bag-in-signature-canvas/CW206.html?frp=CW206+IMXAQ
# Comparable Value: $250
# Sale Price: $149   - Sales Price    - Original Price
# Discount: 40%
# Additional Discount:
# Description: Crossbody,Color Block,Pen Holder,Day Party,Black,Front View
# --------------------------------------------------
# Product: Mini Jamie Camera Bag With Leopard Print
# Item ID: CBL95
# Variation ID: IMXAC
# Product URL: https://www.coach.com/products/mini-jamie-camera-bag-with-leopard-print/CBL95.html?frp=CBL95+IMXAC
# Comparable Value: $328
# Sale Price: $109   - Sales Price    - Original Price
# Discount: 67%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Coach X Peanuts Nolita 19
# Item ID: CBM76
# Variation ID: IMCAH
# Product URL: https://www.coach.com/products/coach-x-peanuts-nolita-19/CBM76.html?frp=CBM76+IMCAH
# Comparable Value: $218
# Sale Price: $87.20   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Gallery Tote Bag
# Item ID: CV402
# Variation ID: IMBLK
# Product URL: https://www.coach.com/products/gallery-tote-bag/CV402.html?frp=CV402+IMBLK
# Comparable Value: $378
# Sale Price: $139   - Sales Price    - Original Price
# Discount: 63%
# Additional Discount:
# Description: Leather,Tote,Logo,Metal,Casual,Black,Front View
# --------------------------------------------------
# Product: Teri Shoulder Bag
# Item ID: CV934
# Variation ID: IMBLK
# Product URL: https://www.coach.com/products/teri-shoulder-bag/CV934.html?frp=CV934+IMBLK
# Comparable Value:
# Sale Price: $219
# Discount:
# Additional Discount:
# Description: Shoulder Bag,Logo,Chain Detail,Metal,Casual,Black,Front View
# --------------------------------------------------
# Product: Satchel Crossbody Bag With Plaid Print
# Item ID: CBI90
# Variation ID: IMY3F
# Product URL: https://www.coach.com/products/satchel-crossbody-bag-with-plaid-print/CBI90.html?frp=CBI90+IMY3F
# Comparable Value: $350
# Sale Price: $139   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Eliza Shoulder Bag With Zipper Closure
# Item ID: CAA93
# Variation ID: IMCHK
# Product URL: https://www.coach.com/products/eliza-shoulder-bag-with-zipper-closure/CAA93.html?frp=CAA93+IMCHK
# Comparable Value: $350
# Sale Price: $149   - Sales Price    - Original Price
# Discount: 57%
# Additional Discount:
# Description: Shoulder Bag,Logo,Casual,White,Front View
# --------------------------------------------------
# Product: Coach X Peanuts Racer Sling Pack In Signature Canvas With Snoopy Print
# Item ID: CBK47
# Variation ID: QBTAM
# Product URL: https://www.coach.com/products/coach-x-peanuts-racer-sling-pack-in-signature-canvas-with-snoopy-print/CBK47.html?frp=CBK47+QBTAM
# Comparable Value: $378
# Sale Price: $151.20   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product:
# Item ID:
# Variation ID:
# Product URL:
# Comparable Value:
# Sale Price:
# Discount:
# Additional Discount:
# Description:
# --------------------------------------------------
# Product: Mini Jamie Camera Bag
# Item ID: CQ875
# Variation ID: IMCHK
# Product URL: https://www.coach.com/products/mini-jamie-camera-bag/CQ875.html?frp=CQ875+IMCHK
# Comparable Value: $278
# Sale Price: $109   - Sales Price    - Original Price
# Discount: 61%
# Additional Discount:
# Description: Leather,Camera Bag,Color Block,Logo,Gold Metal,Casual,White,Front View
# --------------------------------------------------
# Product: Kailey Shoulder Bag
# Item ID: CY707
# Variation ID: IMV2R
# Product URL: https://www.coach.com/products/kailey-shoulder-bag/CY707.html?frp=CY707+IMV2R
# Comparable Value: $350
# Sale Price: $149   - Sales Price    - Original Price
# Discount: 57%
# Additional Discount:
# Description: Leather,Shoulder Bag,Embossed,Logo,Metal,Adjustable,Casual,Brown,Front View
# --------------------------------------------------
# Product: City Tote Bag In Signature Canvas With Coach Graphic
# Item ID: CBI79
# Variation ID: IMY3I
# Product URL: https://www.coach.com/products/city-tote-bag-in-signature-canvas-with-coach-graphic/CBI79.html?frp=CBI79+IMY3I
# Comparable Value: $398
# Sale Price: $149   - Sales Price    - Original Price
# Discount: 63%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Mini Jamie Camera Bag In Signature Canvas With Varsity Stripe
# Item ID: CBM36
# Variation ID: IMY3L
# Product URL: https://www.coach.com/products/mini-jamie-camera-bag-in-signature-canvas-with-varsity-stripe/CBM36.html?frp=CBM36+IMY3L
# Comparable Value: $278
# Sale Price: $109   - Sales Price    - Original Price
# Discount: 61%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Teri Mini Crossbody Bag In Signature Canvas
# Item ID: CW323
# Variation ID: IMXAQ
# Product URL: https://www.coach.com/products/teri-mini-crossbody-bag-in-signature-canvas/CW323.html?frp=CW323+IMXAQ
# Comparable Value:
# Sale Price: $179
# Discount:
# Additional Discount:
# Description: Shoulder Bag,Casual,Black,Front View
# --------------------------------------------------
# Product: Nolita 19 With Leopard Print
# Item ID: CBM66
# Variation ID: IMXAC
# Product URL: https://www.coach.com/products/nolita-19-with-leopard-print/CBM66.html?frp=CBM66+IMXAC
# Comparable Value: $218
# Sale Price: $119   - Sales Price    - Original Price
# Discount: 45%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Warren Mini Belt Bag In Signature Canvas
# Item ID: CW369
# Variation ID: QBMI5
# Product URL: https://www.coach.com/products/warren-mini-belt-bag-in-signature-canvas/CW369.html?frp=CW369+QBMI5
# Comparable Value: $328
# Sale Price: $109   - Sales Price    - Original Price
# Discount: 67%
# Additional Discount:
# Description: Belt Bag,Casual,Black,Front View
# --------------------------------------------------
# Product: City Tote Bag
# Item ID: CR111
# Variation ID: IMBLK
# Product URL: https://www.coach.com/products/city-tote-bag/CR111.html?frp=CR111+IMBLK
# Comparable Value: $398
# Sale Price: $149   - Sales Price    - Original Price
# Discount: 63%
# Additional Discount:
# Description: Leather,Tote,Logo,Casual,Black,Front View
# --------------------------------------------------
# Product: Rowan Satchel Bag In Signature Canvas
# Item ID: CW376
# Variation ID: SVPWH
# Product URL: https://www.coach.com/products/rowan-satchel-bag-in-signature-canvas/CW376.html?frp=CW376+SVPWH
# Comparable Value: $398
# Sale Price: $159   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Satchel,Color Block,Casual,Work,Beige,Front View
# --------------------------------------------------
# Product: Teri Shoulder Bag With Leopard Print
# Item ID: CBH61
# Variation ID: IMXAC
# Product URL: https://www.coach.com/products/teri-shoulder-bag-with-leopard-print/CBH61.html?frp=CBH61+IMXAC
# Comparable Value:
# Sale Price: $219
# Discount:
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Laurel Small Shoulder Bag
# Item ID: CBH16
# Variation ID: IMBLK
# Product URL: https://www.coach.com/products/laurel-small-shoulder-bag/CBH16.html?frp=CBH16+IMBLK
# Comparable Value: $328
# Sale Price: $179   - Sales Price    - Original Price
# Discount: 45%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Brooklyn Shoulder Bag 28
# Item ID: CU068
# Variation ID: B4MPL
# Product URL: https://www.coach.com/products/brooklyn-shoulder-bag-28/CU068.html?frp=CU068+B4MPL
# Comparable Value: $295
# Sale Price:
# Discount:
# Additional Discount:
# Description: Leather,Hobo,Embossed,Word Embellishment,Logo,Casual,Brown,Front View
# --------------------------------------------------
# Product: Sullivan Crossbody Bag In Signature Canvas
# Item ID: CAT78
# Variation ID: QBXAM
# Product URL: https://www.coach.com/products/sullivan-crossbody-bag-in-signature-canvas/CAT78.html?frp=CAT78+QBXAM
# Comparable Value: $278
# Sale Price: $129   - Sales Price    - Original Price
# Discount: 54%
# Additional Discount:
# Description: Leather,Canvas,Crossbody,Color Block,Adjustable,Casual,Multi Color,Front View
# --------------------------------------------------
# Product: Rowan Large Satchel Bag
# Item ID: CV960
# Variation ID: IMBLK
# Product URL: https://www.coach.com/products/rowan-large-satchel-bag/CV960.html?frp=CV960+IMBLK
# Comparable Value: $450
# Sale Price: $199   - Sales Price    - Original Price
# Discount: 56%
# Additional Discount:
# Description: Satchel,Logo,Work,Black,Front View
# --------------------------------------------------
# Product: Slim Crossbody Bag
# Item ID: CAT21
# Variation ID: IMCHK
# Product URL: https://www.coach.com/products/slim-crossbody-bag/CAT21.html?frp=CAT21+IMCHK
# Comparable Value: $250
# Sale Price: $99   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Crossbody,Logo,Metal,Casual,White,Front View
# --------------------------------------------------
# Product: Teri Hobo Bag
# Item ID: CV935
# Variation ID: IMBLK
# Product URL: https://www.coach.com/products/teri-hobo-bag/CV935.html?frp=CV935+IMBLK
# Comparable Value:
# Sale Price: $229
# Discount:
# Additional Discount:
# Description: Shoulder Bag,Metal,Logo,Casual,Black,Front View
# --------------------------------------------------
# Product: Mollie Tote Bag In Signature Canvas
# Item ID: CV967
# Variation ID: IMXAQ
# Product URL: https://www.coach.com/products/mollie-tote-bag-in-signature-canvas/CV967.html?frp=CV967+IMXAQ
# Comparable Value: $428
# Sale Price: $189   - Sales Price    - Original Price
# Discount: 56%
# Additional Discount:
# Description: Tote,Casual,Multi Color,Front View
# --------------------------------------------------
# Product: Gallery Tote Bag In Signature Canvas With Stripe Print
# Item ID: CBM18
# Variation ID: IMTAM
# Product URL: https://www.coach.com/products/gallery-tote-bag-in-signature-canvas-with-stripe-print/CBM18.html?frp=CBM18+IMTAM
# Comparable Value: $378
# Sale Price: $139   - Sales Price    - Original Price
# Discount: 63%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Laurel Large Shoulder Bag
# Item ID: CY684
# Variation ID: IMCHK
# Product URL: https://www.coach.com/products/laurel-large-shoulder-bag/CY684.html?frp=CY684+IMCHK
# Comparable Value: $498
# Sale Price: $229   - Sales Price    - Original Price
# Discount: 54%
# Additional Discount:
# Description: Leather,Shoulder Bag,Logo,Metal,Casual,White,Front View
# --------------------------------------------------
# Product: Teri Mini Crossbody Bag
# Item ID: CW309
# Variation ID: IMCHK
# Product URL: https://www.coach.com/products/teri-mini-crossbody-bag/CW309.html?frp=CW309+IMCHK
# Comparable Value:
# Sale Price: $179
# Discount:
# Additional Discount:
# Description: Shoulder Bag,Metal,Logo,Casual,Day Party,White,Front View
# --------------------------------------------------
# Product: Eliza Shoulder Bag
# Item ID: CBI00
# Variation ID: IMLN6
# Product URL: https://www.coach.com/products/eliza-shoulder-bag/CBI00.html?frp=CBI00+IMLN6
# Comparable Value: $350
# Sale Price: $149   - Sales Price    - Original Price
# Discount: 57%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Georgia Satchel Bag
# Item ID: CR156
# Variation ID: IMBLK
# Product URL: https://www.coach.com/products/georgia-satchel-bag/CR156.html?frp=CR156+IMBLK
# Comparable Value: $378
# Sale Price: $159   - Sales Price    - Original Price
# Discount: 58%
# Additional Discount:
# Description: Leather,Satchel,Logo,Work,Black,Front View
# --------------------------------------------------
# Product: Teri Hobo Bag In Signature Canvas
# Item ID: CV940
# Variation ID: IMXAQ
# Product URL: https://www.coach.com/products/teri-hobo-bag-in-signature-canvas/CV940.html?frp=CV940+IMXAQ
# Comparable Value: $428
# Sale Price: $229   - Sales Price    - Original Price
# Discount: 46%
# Additional Discount:
# Description: Shoulder Bag,Casual,Black,Front View
# --------------------------------------------------
# Product: Smith Tote Bag
# Item ID: CBM10
# Variation ID: IMCAH
# Product URL: https://www.coach.com/products/smith-tote-bag/CBM10.html?frp=CBM10+IMCAH
# Comparable Value: $428
# Sale Price: $179   - Sales Price    - Original Price
# Discount: 58%
# Additional Discount:
# Description: Leather,Tote,Stripe,Casual,White,Front View
# --------------------------------------------------
# Product: Hadley Turnlock Tote Bag
# Item ID: CAL17
# Variation ID: IMV2R
# Product URL: https://www.coach.com/products/hadley-turnlock-tote-bag/CAL17.html?frp=CAL17+IMV2R
# Comparable Value: $325
# Sale Price: $179   - Sales Price    - Original Price
# Discount: 45%
# Additional Discount:
# Description: Leather,Tote,Logo,Metal,Gold Plated,Casual,Brown,Front View
# --------------------------------------------------
# Product: Tote Bag 20 With Coach Graphic
# Item ID: CBK29
# Variation ID: QBLBO
# Product URL: https://www.coach.com/products/tote-bag-20-with-coach-graphic/CBK29.html?frp=CBK29+QBLBO
# Comparable Value: $228
# Sale Price: $129   - Sales Price    - Original Price
# Discount: 43%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Amelia Saddle Bag
# Item ID: CP107
# Variation ID: IMBLK
# Product URL: https://www.coach.com/products/amelia-saddle-bag/CP107.html?frp=CP107+IMBLK
# Comparable Value: $398
# Sale Price: $159   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Leather,Saddle Bag,Logo,Casual,Black,Front View
# --------------------------------------------------
# Product: Gallery Tote Bag In Signature Canvas
# Item ID: CW381
# Variation ID: IMXU5
# Product URL: https://www.coach.com/products/gallery-tote-bag-in-signature-canvas/CW381.html?frp=CW381+IMXU5
# Comparable Value: $378
# Sale Price: $139   - Sales Price    - Original Price
# Discount: 63%
# Additional Discount:
# Description: Tote,Casual,White,Front View
# --------------------------------------------------
# Product: Nolita 19 In Sketch Signature Canvas
# Item ID: CBM72
# Variation ID: SVNB9
# Product URL: https://www.coach.com/products/nolita-19-in-sketch-signature-canvas/CBM72.html?frp=CBM72+SVNB9
# Comparable Value: $188
# Sale Price: $119   - Sales Price    - Original Price
# Discount: 37%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Teri Shoulder Bag
# Item ID: CBH59
# Variation ID: IMY6N
# Product URL: https://www.coach.com/products/teri-shoulder-bag/CBH59.html?frp=CBH59+IMY6N
# Comparable Value:
# Sale Price: $140
# Discount:
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Mini Jamie Camera Bag In Signature Canvas
# Item ID: CY752
# Variation ID: IMXAQ
# Product URL: https://www.coach.com/products/mini-jamie-camera-bag-in-signature-canvas/CY752.html?frp=CY752+IMXAQ
# Comparable Value: $278
# Sale Price: $109   - Sales Price    - Original Price
# Discount: 61%
# Additional Discount:
# Description: Canvas,Camera Bag,Adjustable,Casual,Brown,Front View
# --------------------------------------------------
# Product: City Large Bucket Bag
# Item ID: CT803
# Variation ID: IMCHK
# Product URL: https://www.coach.com/products/city-large-bucket-bag/CT803.html?frp=CT803+IMCHK
# Comparable Value: $450
# Sale Price: $139   - Sales Price    - Original Price
# Discount: 69%
# Additional Discount:
# Description: Bucket,Metal,Logo,Casual,White,Front View
# --------------------------------------------------
# Product: Laurel Shoulder Bag In Signature Canvas
# Item ID: CV975
# Variation ID: IMXAQ
# Product URL: https://www.coach.com/products/laurel-shoulder-bag-in-signature-canvas/CV975.html?frp=CV975+IMXAQ
# Comparable Value: $428
# Sale Price: $219   - Sales Price    - Original Price
# Discount: 49%
# Additional Discount:
# Description: Canvas,Shoulder Bag,Metal,Tag Embellishment,Logo,Casual,Black,Front View
# --------------------------------------------------
# Product: Stanton Crossbody Bag In Signature Canvas
# Item ID: CBI33
# Variation ID: QBYBK
# Product URL: https://www.coach.com/products/stanton-crossbody-bag-in-signature-canvas/CBI33.html?frp=CBI33+QBYBK
# Comparable Value: $250
# Sale Price: $99   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Georgia Satchel Bag
# Item ID: CBM11
# Variation ID: IMTN2
# Product URL: https://www.coach.com/products/georgia-satchel-bag/CBM11.html?frp=CBM11+IMTN2
# Comparable Value: $378
# Sale Price: $159   - Sales Price    - Original Price
# Discount: 58%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Smith Tote Bag In Signature Jacquard
# Item ID: CY368
# Variation ID: SBKBK
# Product URL: https://www.coach.com/products/smith-tote-bag-in-signature-jacquard/CY368.html?frp=CY368+SBKBK
# Comparable Value: $428
# Sale Price: $179   - Sales Price    - Original Price
# Discount: 58%
# Additional Discount:
# Description: Cotton,Cotton Blend,Tote,Expandable,Pen Holder,Work,Casual,Black,Front View
# --------------------------------------------------
# Product: Satchel Crossbody Bag In Signature Canvas
# Item ID: CW197
# Variation ID: IMY3L
# Product URL: https://www.coach.com/products/satchel-crossbody-bag-in-signature-canvas/CW197.html?frp=CW197+IMY3L
# Comparable Value: $350
# Sale Price: $139   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Canvas,Crossbody,Casual,,Front View
# --------------------------------------------------
# Product: Rowan Large Satchel Bag In Signature Canvas
# Item ID: CV959
# Variation ID: SVPWH
# Product URL: https://www.coach.com/products/rowan-large-satchel-bag-in-signature-canvas/CV959.html?frp=CV959+SVPWH
# Comparable Value: $450
# Sale Price: $199   - Sales Price    - Original Price
# Discount: 56%
# Additional Discount:
# Description: Satchel,Work,Casual,Beige,Front View
# --------------------------------------------------
# Product: Hailey Flap Bag With Plaid Print
# Item ID: CBI56
# Variation ID: IMPMC
# Product URL: https://www.coach.com/products/hailey-flap-bag-with-plaid-print/CBI56.html?frp=CBI56+IMPMC
# Comparable Value: $298
# Sale Price: $149   - Sales Price    - Original Price
# Discount: 50%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Eliza Top Handle Bag
# Item ID: CT852
# Variation ID: QB%2FBK
# Product URL: https://www.coach.com/products/eliza-top-handle-bag/CT852.html?frp=CT852+QB%2FBK
# Comparable Value: $478
# Sale Price: $159   - Sales Price    - Original Price
# Discount: 67%
# Additional Discount:
# Description: Satchel,Logo,Pen Holder,Casual,Work,Black,Front View
# --------------------------------------------------
# Product: West Backpack In Signature Canvas With Varsity Stripe
# Item ID: CV922
# Variation ID: QBOH0
# Product URL: https://www.coach.com/products/west-backpack-in-signature-canvas-with-varsity-stripe/CV922.html?frp=CV922+QBOH0
# Comparable Value: $598
# Sale Price: $219   - Sales Price    - Original Price
# Discount: 63%
# Additional Discount:
# Description: Backpack,Stripe,Casual,Black,Front View
# --------------------------------------------------
# Product: Mini Jamie Camera Bag With Plaid Print
# Item ID: CBM37
# Variation ID: IMPMC
# Product URL: https://www.coach.com/products/mini-jamie-camera-bag-with-plaid-print/CBM37.html?frp=CBM37+IMPMC
# Comparable Value: $278
# Sale Price: $109   - Sales Price    - Original Price
# Discount: 61%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Jude Duffle Bag
# Item ID: CBH18
# Variation ID: IMV2R
# Product URL: https://www.coach.com/products/jude-duffle-bag/CBH18.html?frp=CBH18+IMV2R
# Comparable Value: $450
# Sale Price: $179   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Leather,Crossbody,Logo,Metal,Gold Metal,Casual,Brown,Front View
# --------------------------------------------------
# Product: Carmen Mini Crossbody Bag With Quilting
# Item ID: CAK89
# Variation ID: SV%2FDE
# Product URL: https://www.coach.com/products/carmen-mini-crossbody-bag-with-quilting/CAK89.html?frp=CAK89+SV%2FDE
# Comparable Value: $350
# Sale Price: $139   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Leather,Denim,Cotton,Crossbody,Metal,Tassel,Logo,Casual,Day Party,Blue,Front View
# --------------------------------------------------
# Product: Laurel Shoulder Bag
# Item ID: CBG99
# Variation ID: IMTN2
# Product URL: https://www.coach.com/products/laurel-shoulder-bag/CBG99.html?frp=CBG99+IMTN2
# Comparable Value: $428
# Sale Price: $219   - Sales Price    - Original Price
# Discount: 49%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Mini Klare Crossbody Bag
# Item ID: CZ987
# Variation ID: IMTAU
# Product URL: https://www.coach.com/products/mini-klare-crossbody-bag/CZ987.html?frp=CZ987+IMTAU
# Comparable Value: $328
# Sale Price: $149   - Sales Price    - Original Price
# Discount: 55%
# Additional Discount:
# Description: Crossbody,Logo,Metal,Day Party,Beige,Front View
# --------------------------------------------------
# Product: Rowan Satchel Bag In Signature Canvas
# Item ID: CV961
# Variation ID: IMXAQ
# Product URL: https://www.coach.com/products/rowan-satchel-bag-in-signature-canvas/CV961.html?frp=CV961+IMXAQ
# Comparable Value: $398
# Sale Price: $159   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Satchel,Piping,Casual,Work,Gray,Front View
# --------------------------------------------------
# Product: Jamie Camera Bag
# Item ID: CR110
# Variation ID: IMBLK
# Product URL: https://www.coach.com/products/jamie-camera-bag/CR110.html?frp=CR110+IMBLK
# Comparable Value: $350
# Sale Price: $139   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Leather,Camera Bag,Logo,Casual,Black,Front View
# --------------------------------------------------
# Product: Tabby Shoulder Bag 26 With Pillow Quilting
# Item ID: CP150
# Variation ID: B4%2FBK
# Product URL: https://www.coach.com/products/tabby-shoulder-bag-26-with-pillow-quilting/CP150.html?frp=CP150+B4%2FBK
# Comparable Value: $550
# Sale Price:
# Discount:
# Additional Discount:
# Description: Leather,Shoulder Bag,Logo,Metal,Shoulder Guard,Silver Metal,Day Party,Black,Front View
# --------------------------------------------------
# Product: Mollie Tote Bag
# Item ID: CV968
# Variation ID: SV%2FBK
# Product URL: https://www.coach.com/products/mollie-tote-bag/CV968.html?frp=CV968+SV%2FBK
# Comparable Value: $428
# Sale Price: $189   - Sales Price    - Original Price
# Discount: 56%
# Additional Discount:
# Description: Tote,Logo,Work,Casual,Black,Front View
# --------------------------------------------------
# Product: Eliza Top Handle Bag In Signature Canvas
# Item ID: CW012
# Variation ID: IMXAQ
# Product URL: https://www.coach.com/products/eliza-top-handle-bag-in-signature-canvas/CW012.html?frp=CW012+IMXAQ
# Comparable Value: $478
# Sale Price: $159   - Sales Price    - Original Price
# Discount: 67%
# Additional Discount:
# Description: Satchel,Color Block,Pen Holder,Casual,Work,Black,Front View
# --------------------------------------------------
# Product: Racer Sling Pack In Signature Canvas
# Item ID: CV763
# Variation ID: QBNRX
# Product URL: https://www.coach.com/products/racer-sling-pack-in-signature-canvas/CV763.html?frp=CV763+QBNRX
# Comparable Value: $328
# Sale Price: $169   - Sales Price    - Original Price
# Discount: 48%
# Additional Discount:
# Description: Slingback,Color Block,Casual,Multi Color,Front View
# --------------------------------------------------
# Product: Aden Crossbody Bag
# Item ID: CS044
# Variation ID: QB%2FBK
# Product URL: https://www.coach.com/products/aden-crossbody-bag/CS044.html?frp=CS044+QB%2FBK
# Comparable Value: $198
# Sale Price: $79   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Calfskin Leather,Leather,Crossbody,Pen Holder,Casual,Black,Front View
# --------------------------------------------------
# Product: Aden Crossbody Bag In Signature Canvas
# Item ID: CW364
# Variation ID: QBMI5
# Product URL: https://www.coach.com/products/aden-crossbody-bag-in-signature-canvas/CW364.html?frp=CW364+QBMI5
# Comparable Value: $198
# Sale Price: $79   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Canvas,Crossbody,Pen Holder,Casual,Black,Front View
# --------------------------------------------------
# Product: Large Court Backpack In Signature Canvas
# Item ID: CZ175
# Variation ID: IMXAQ
# Product URL: https://www.coach.com/products/large-court-backpack-in-signature-canvas/CZ175.html?frp=CZ175+IMXAQ
# Comparable Value: $498
# Sale Price: $149.40   - Sales Price    - Original Price
# Discount: 70%
# Additional Discount:
# Description: Leather,Canvas,Backpack,Color Block,Adjustable,Casual,Brown,Front View
# --------------------------------------------------
# Product: Hadley Convertible Crossbody Bag
# Item ID: CW002
# Variation ID: IMBLK
# Product URL: https://www.coach.com/products/hadley-convertible-crossbody-bag/CW002.html?frp=CW002+IMBLK
# Comparable Value: $325
# Sale Price: $199   - Sales Price    - Original Price
# Discount: 39%
# Additional Discount:
# Description: Leather,Crossbody,Metal,Logo,Gold Metal,Casual,Black,Front View
# --------------------------------------------------
# Product: Wyatt Crossbody Bag
# Item ID: CBK46
# Variation ID: QBY42
# Product URL: https://www.coach.com/products/wyatt-crossbody-bag/CBK46.html?frp=CBK46+QBY42
# Comparable Value: $328
# Sale Price: $129   - Sales Price    - Original Price
# Discount: 61%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Klare Wallet With Chain In Blocked Signature Canvas
# Item ID: CBI21
# Variation ID: IMXI9
# Product URL: https://www.coach.com/products/klare-wallet-with-chain-in-blocked-signature-canvas/CBI21.html?frp=CBI21+IMXI9
# Comparable Value: $250
# Sale Price: $119   - Sales Price    - Original Price
# Discount: 52%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Crosby Backpack
# Item ID: CY279
# Variation ID: B4%2FBK
# Product URL: https://www.coach.com/products/crosby-backpack/CY279.html?frp=CY279+B4%2FBK
# Comparable Value: $495
# Sale Price: $247.50   - Sales Price    - Original Price
# Discount: 50%
# Additional Discount:
# Description: Backpack,Logo,Casual,Black,Front View
# --------------------------------------------------
# Product: Graham Crossbody Bag In Signature Canvas
# Item ID: CV921
# Variation ID: QBNRX
# Product URL: https://www.coach.com/products/graham-crossbody-bag-in-signature-canvas/CV921.html?frp=CV921+QBNRX
# Comparable Value: $328
# Sale Price: $129   - Sales Price    - Original Price
# Discount: 61%
# Additional Discount:
# Description: Canvas,Crossbody,Color Block,Casual,Multi Color,Front View
# --------------------------------------------------
# Product: Brooklyn Shoulder Bag 39
# Item ID: CU044
# Variation ID: B4%2FBK
# Product URL: https://www.coach.com/products/brooklyn-shoulder-bag-39/CU044.html?frp=CU044+B4%2FBK
# Comparable Value: $495
# Sale Price:
# Discount:
# Additional Discount:
# Description: Hobo,Embossed,Word Embellishment,Logo,Casual,Black,Front View
# --------------------------------------------------
# Product: Teri Mini Crossbody Bag
# Item ID: CW310
# Variation ID: SV%2FBK
# Product URL: https://www.coach.com/products/teri-mini-crossbody-bag/CW310.html?frp=CW310+SV%2FBK
# Comparable Value:
# Sale Price: $179
# Discount:
# Additional Discount:
# Description: Shoulder Bag,Metal,Logo,Casual,Black,Front View
# --------------------------------------------------
# Product: Coach X Peanuts Satchel Crossbody Bag In Signature Canvas With Lucy
# Item ID: CBJ62
# Variation ID: IMBCV
# Product URL: https://www.coach.com/products/coach-x-peanuts-satchel-crossbody-bag-in-signature-canvas-with-lucy/CBJ62.html?frp=CBJ62+IMBCV
# Comparable Value: $398
# Sale Price: $159.20   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Faye Shoulder Bag With Ruching
# Item ID: CV529
# Variation ID: IMCHK
# Product URL: https://www.coach.com/products/faye-shoulder-bag-with-ruching/CV529.html?frp=CV529+IMCHK
# Comparable Value: $275
# Sale Price: $199   - Sales Price    - Original Price
# Discount: 28%
# Additional Discount:
# Description: Shoulder Bag,Drawstring,Logo,Ball Embellishment,Metal,Casual,White,Front View
# --------------------------------------------------
# Product: West Backpack In Signature Canvas
# Item ID: CV925
# Variation ID: QBMI5
# Product URL: https://www.coach.com/products/west-backpack-in-signature-canvas/CV925.html?frp=CV925+QBMI5
# Comparable Value: $550
# Sale Price: $219   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Backpack,Casual,Black,Front View
# --------------------------------------------------
# Product: Dylan Tote Bag In Signature Canvas With Varsity Stripe
# Item ID: CBI38
# Variation ID: QBNI9
# Product URL: https://www.coach.com/products/dylan-tote-bag-in-signature-canvas-with-varsity-stripe/CBI38.html?frp=CBI38+QBNI9
# Comparable Value: $428
# Sale Price: $129   - Sales Price    - Original Price
# Discount: 70%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Teri Hobo Bag In Signature Canvas
# Item ID: CAL52
# Variation ID: IMY3L
# Product URL: https://www.coach.com/products/teri-hobo-bag-in-signature-canvas/CAL52.html?frp=CAL52+IMY3L
# Comparable Value:
# Sale Price: $229
# Discount:
# Additional Discount:
# Description: Shoulder Bag,Logo,Adjustable,Silver Metal,Casual,,Front View
# --------------------------------------------------
# Product: Rowan Satchel Bag
# Item ID: CV962
# Variation ID: IMBLK
# Product URL: https://www.coach.com/products/rowan-satchel-bag/CV962.html?frp=CV962+IMBLK
# Comparable Value: $398
# Sale Price: $159   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Satchel,Logo,Work,Casual,Black,Front View
# --------------------------------------------------
# Product: Laurel Small Shoulder Bag In Signature Canvas
# Item ID: CBH15
# Variation ID: SVPWH
# Product URL: https://www.coach.com/products/laurel-small-shoulder-bag-in-signature-canvas/CBH15.html?frp=CBH15+SVPWH
# Comparable Value: $328
# Sale Price: $179   - Sales Price    - Original Price
# Discount: 45%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Twisted Teri Shoulder Bag In Signature Canvas
# Item ID: CBI02
# Variation ID: IMXIS
# Product URL: https://www.coach.com/products/twisted-teri-shoulder-bag-in-signature-canvas/CBI02.html?frp=CBI02+IMXIS
# Comparable Value:
# Sale Price: $199
# Discount:
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Satchel Crossbody
# Item ID: CT776
# Variation ID: IMV2R
# Product URL: https://www.coach.com/products/satchel-crossbody/CT776.html?frp=CT776+IMV2R
# Comparable Value: $350
# Sale Price: $139   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Leather,Crossbody,Logo,Embossed,Metal,Day Party,Brown,Front View
# --------------------------------------------------
# Product: Ellie File Bag
# Item ID: CU960
# Variation ID: IMCHK
# Product URL: https://www.coach.com/products/ellie-file-bag/CU960.html?frp=CU960+IMCHK
# Comparable Value: $350
# Sale Price: $139   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Leather,Crossbody,Metal,Logo,Casual,White,Front View
# --------------------------------------------------
# Product: Ethan Pack In Signature Canvas
# Item ID: CZ393
# Variation ID: QBMI5
# Product URL: https://www.coach.com/products/ethan-pack-in-signature-canvas/CZ393.html?frp=CZ393+QBMI5
# Comparable Value: $378
# Sale Price: $132.30   - Sales Price    - Original Price
# Discount: 65%
# Additional Discount:
# Description: Canvas,Calfskin Leather,Slingback,Adjustable,Casual,Black,Front View
# --------------------------------------------------
# Product: Hadley Turnlock Tote
# Item ID: CBH00
# Variation ID: IMTN2
# Product URL: https://www.coach.com/products/hadley-turnlock-tote/CBH00.html?frp=CBH00+IMTN2
# Comparable Value: $325
# Sale Price: $179   - Sales Price    - Original Price
# Discount: 45%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Court Backpack In Signature Canvas
# Item ID: CZ176
# Variation ID: IMXHE
# Product URL: https://www.coach.com/products/court-backpack-in-signature-canvas/CZ176.html?frp=CZ176+IMXHE
# Comparable Value: $450
# Sale Price: $135   - Sales Price    - Original Price
# Discount: 70%
# Additional Discount:
# Description: Leather,Canvas,Backpack,Metal,Color Block,Logo,Adjustable,Casual,Multi Color,Front View
# --------------------------------------------------
# Product: Elias Belt Bag In Signature Canvas
# Item ID: CZ400
# Variation ID: QBMI5
# Product URL: https://www.coach.com/products/elias-belt-bag-in-signature-canvas/CZ400.html?frp=CZ400+QBMI5
# Comparable Value: $350
# Sale Price: $129   - Sales Price    - Original Price
# Discount: 63%
# Additional Discount:
# Description: Coin,Belt Bag,Casual,Black,Front View
# --------------------------------------------------
# Product: Klare Crossbody Bag With Plaid Print
# Item ID: CBI85
# Variation ID: IMLG6
# Product URL: https://www.coach.com/products/klare-crossbody-bag-with-plaid-print/CBI85.html?frp=CBI85+IMLG6
# Comparable Value: $398
# Sale Price: $199   - Sales Price    - Original Price
# Discount: 50%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Axel Crossbody Bag In Signature Canvas
# Item ID: CV762
# Variation ID: QBMI5
# Product URL: https://www.coach.com/products/axel-crossbody-bag-in-signature-canvas/CV762.html?frp=CV762+QBMI5
# Comparable Value: $398
# Sale Price: $129   - Sales Price    - Original Price
# Discount: 68%
# Additional Discount:
# Description: Crossbody,Pouch,Logo,Casual,Black,Front View
# --------------------------------------------------
# Product: Klare Crossbody Bag In Signature Canvas
# Item ID: CV978
# Variation ID: SVPWH
# Product URL: https://www.coach.com/products/klare-crossbody-bag-in-signature-canvas/CV978.html?frp=CV978+SVPWH
# Comparable Value: $295
# Sale Price: $199   - Sales Price    - Original Price
# Discount: 33%
# Additional Discount:
# Description: Crossbody,Chain Detail,Pattern,Day Party,Beige,Front View
# --------------------------------------------------
# Product: Hadley Convertible Crossbody Bag With Signature Canvas
# Item ID: CAK50
# Variation ID: IMLG6
# Product URL: https://www.coach.com/products/hadley-convertible-crossbody-bag-with-signature-canvas/CAK50.html?frp=CAK50+IMLG6
# Comparable Value: $428
# Sale Price: $199   - Sales Price    - Original Price
# Discount: 54%
# Additional Discount:
# Description: Canvas,Cotton,Crossbody,Color Block,Adjustable,Casual,Beige,Front View
# --------------------------------------------------
# Product: Jamie Camera Bag In Signature Canvas With Stripe
# Item ID: CZ185
# Variation ID: SVPWH
# Product URL: https://www.coach.com/products/jamie-camera-bag-in-signature-canvas-with-stripe/CZ185.html?frp=CZ185+SVPWH
# Comparable Value: $350
# Sale Price: $139   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Leather,Canvas,Camera Bag,Color Block,Adjustable,Casual,Beige,Front View
# --------------------------------------------------
# Product: Hadley Convertible Crossbody Bag
# Item ID: CAL93
# Variation ID: IMXUB
# Product URL: https://www.coach.com/products/hadley-convertible-crossbody-bag/CAL93.html?frp=CAL93+IMXUB
# Comparable Value: $428
# Sale Price: $128.40   - Sales Price    - Original Price
# Discount: 70%
# Additional Discount:
# Description: Crossbody,Straw,Color Block,Logo,Adjustable,Casual,Beige,Front View
# --------------------------------------------------
# Product: Savannah Carryall Bag
# Item ID: CAL56
# Variation ID: IMBLK
# Product URL: https://www.coach.com/products/savannah-carryall-bag/CAL56.html?frp=CAL56+IMBLK
# Comparable Value: $498
# Sale Price: $219   - Sales Price    - Original Price
# Discount: 56%
# Additional Discount:
# Description: Satchel,Logo,Work,Black,Front View
# --------------------------------------------------
# Product: Sullivan Crossbody Bag
# Item ID: CAT81
# Variation ID: JIBLK
# Product URL: https://www.coach.com/products/sullivan-crossbody-bag/CAT81.html?frp=CAT81+JIBLK
# Comparable Value: $278
# Sale Price: $129   - Sales Price    - Original Price
# Discount: 54%
# Additional Discount:
# Description: Calfskin Leather,Crossbody,Embossed,Logo,Casual,Black,Front View
# --------------------------------------------------
# Product: Ellie File Bag In Signature Canvas
# Item ID: CU959
# Variation ID: IMCBI
# Product URL: https://www.coach.com/products/ellie-file-bag-in-signature-canvas/CU959.html?frp=CU959+IMCBI
# Comparable Value: $350
# Sale Price: $139   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description:
# --------------------------------------------------
# Product: Mollie Tote Bag 25 In Signature Canvas
# Item ID: CV965
# Variation ID: SVPWH
# Product URL: https://www.coach.com/products/mollie-tote-bag-25-in-signature-canvas/CV965.html?frp=CV965+SVPWH
# Comparable Value: $378
# Sale Price: $189   - Sales Price    - Original Price
# Discount: 50%
# Additional Discount:
# Description:
# --------------------------------------------------
# Product: Carry All Pouch In Signature Canvas
# Item ID: CY985
# Variation ID: QBMI5
# Product URL: https://www.coach.com/products/carry-all-pouch-in-signature-canvas/CY985.html?frp=CY985+QBMI5
# Comparable Value: $250
# Sale Price: $100   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description:
# --------------------------------------------------
# Product: Ashton Bag
# Item ID: CM079
# Variation ID: SV%2FHA
# Product URL: https://www.coach.com/products/ashton-bag/CM079.html?frp=CM079+SV%2FHA
# Comparable Value: $295
# Sale Price: $199   - Sales Price    - Original Price
# Discount: 33%
# Additional Discount:
# Description:
# --------------------------------------------------
# Product: Eliza Top Handle
# Item ID: CP006
# Variation ID: IMCHK
# Product URL: https://www.coach.com/products/eliza-top-handle/CP006.html?frp=CP006+IMCHK
# Comparable Value: $478
# Sale Price: $159   - Sales Price    - Original Price
# Discount: 67%
# Additional Discount:
# Description: Calfskin Leather,Satchel,Logo,Gusset,Silver Metal,Day Party,Work,White,Front View
# --------------------------------------------------
# Product: Twisted Teri Shoulder Bag
# Item ID: CBI01
# Variation ID: SVWYE
# Product URL: https://www.coach.com/products/twisted-teri-shoulder-bag/CBI01.html?frp=CBI01+SVWYE
# Comparable Value:
# Sale Price: $199
# Discount:
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Mini Rowan Crossbody Bag In Colorblock Signature Canvas
# Item ID: CBM68
# Variation ID: IMY3L
# Product URL: https://www.coach.com/products/mini-rowan-crossbody-bag-in-colorblock-signature-canvas/CBM68.html?frp=CBM68+IMY3L
# Comparable Value: $328
# Sale Price: $159   - Sales Price    - Original Price
# Discount: 52%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: West Pack In Signature Canvas
# Item ID: CV924
# Variation ID: QBMI5
# Product URL: https://www.coach.com/products/west-pack-in-signature-canvas/CV924.html?frp=CV924+QBMI5
# Comparable Value: $350
# Sale Price: $119   - Sales Price    - Original Price
# Discount: 66%
# Additional Discount:
# Description: Canvas,Calfskin Leather,Slingback,Color Block,Embossed,Logo,Adjustable,Casual,Black,Front View
# --------------------------------------------------
# Product: Coach X Peanuts Satchel Crossbody Bag In Signature Canvas With Charlie Brown
# Item ID: CBJ63
# Variation ID: SVMMK
# Product URL: https://www.coach.com/products/coach-x-peanuts-satchel-crossbody-bag-in-signature-canvas-with-charlie-brown/CBJ63.html?frp=CBJ63+SVMMK
# Comparable Value: $398
# Sale Price: $159.20   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Large City Tote Bag In Signature Canvas With Stripe
# Item ID: CBI03
# Variation ID: SVN2V
# Product URL: https://www.coach.com/products/large-city-tote-bag-in-signature-canvas-with-stripe/CBI03.html?frp=CBI03+SVN2V
# Comparable Value: $450
# Sale Price: $169   - Sales Price    - Original Price
# Discount: 62%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Racer Sling Pack
# Item ID: CX071
# Variation ID: QB%2FBK
# Product URL: https://www.coach.com/products/racer-sling-pack/CX071.html?frp=CX071+QB%2FBK
# Comparable Value: $328
# Sale Price: $169   - Sales Price    - Original Price
# Discount: 48%
# Additional Discount:
# Description: Calfskin Leather,Slingback,Applique,Embossed,Logo,Adjustable,Casual,Black,Front View
# --------------------------------------------------
# Product: Klare Wallet With Chain
# Item ID: CBI22
# Variation ID: IMSMU
# Product URL: https://www.coach.com/products/klare-wallet-with-chain/CBI22.html?frp=CBI22+IMSMU
# Comparable Value: $250
# Sale Price: $119   - Sales Price    - Original Price
# Discount: 52%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Tote Bag 38 With Coach Graphic
# Item ID: CBI40
# Variation ID: QBNI9
# Product URL: https://www.coach.com/products/tote-bag-38-with-coach-graphic/CBI40.html?frp=CBI40+QBNI9
# Comparable Value: $450
# Sale Price: $180   - Sales Price    - Original Price
# Discount: 60%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Hadley Mini Crossbody Bag
# Item ID: CBM63
# Variation ID: IMTN2
# Product URL: https://www.coach.com/products/hadley-mini-crossbody-bag/CBM63.html?frp=CBM63+IMTN2
# Comparable Value: $225
# Sale Price: $149   - Sales Price    - Original Price
# Discount: 34%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Tabby Shoulder Bag 26 With Quilting
# Item ID: CW594
# Variation ID: V5XAU
# Product URL: https://www.coach.com/products/tabby-shoulder-bag-26-with-quilting/CW594.html?frp=CW594+V5XAU
# Comparable Value: $550
# Sale Price: $330   - Sales Price    - Original Price
# Discount: 40%
# Additional Discount:
# Description: Leather,Shoulder Bag,Logo,Shoulder Guard,Compact,Silver Metal,Party,Casual,Metallic,Front View
# --------------------------------------------------
# Product: Maggie Tote Bag
# Item ID: CY667
# Variation ID: SV%2FBK
# Product URL: https://www.coach.com/products/maggie-tote-bag/CY667.html?frp=CY667+SV%2FBK
# Comparable Value: $598
# Sale Price: $229   - Sales Price    - Original Price
# Discount: 62%
# Additional Discount:
# Description: Leather,Crocodile,Tote,Logo,Metal,Work,Black,Front View
# --------------------------------------------------
# Product: Tabby Shoulder Bag 26 With Quilting
# Item ID: CW594
# Variation ID: V5XAU
# Product URL: https://www.coach.com/products/tabby-shoulder-bag-26-with-quilting/CW594.html?frp=CW594+V5XAU
# Comparable Value: $550
# Sale Price: $330   - Sales Price    - Original Price
# Discount: 40%
# Additional Discount:
# Description: Leather,Shoulder Bag,Logo,Shoulder Guard,Compact,Silver Metal,Party,Casual,Metallic,Front View
# --------------------------------------------------
# Product: Maggie Tote Bag
# Item ID: CY667
# Variation ID: SV%2FBK
# Product URL: https://www.coach.com/products/maggie-tote-bag/CY667.html?frp=CY667+SV%2FBK
# Comparable Value: $598
# Sale Price: $229   - Sales Price    - Original Price
# Discount: 62%
# Additional Discount:
# Description: Leather,Crocodile,Tote,Logo,Metal,Work,Black,Front View
# --------------------------------------------------
# Product: Sullivan Flap Crossbody Bag In Signature Canvas
# Item ID: CZ396
# Variation ID: QBMI5
# Product URL: https://www.coach.com/products/sullivan-flap-crossbody-bag-in-signature-canvas/CZ396.html?frp=CZ396+QBMI5
# Comparable Value: $350
# Sale Price: $119   - Sales Price    - Original Price
# Discount: 66%
# Additional Discount:
# Description: Leather,Canvas,Crossbody,Adjustable,Casual,Black,Front View
# --------------------------------------------------
# Product: Maggie Tote Bag
# Item ID: CY666
# Variation ID: IMV2R
# Product URL: https://www.coach.com/products/maggie-tote-bag/CY666.html?frp=CY666+IMV2R
# Comparable Value: $550
# Sale Price: $229   - Sales Price    - Original Price
# Discount: 58%
# Additional Discount:
# Description: Leather,Tote,Metal,Embossed,Logo,Work,Brown,Front View
# --------------------------------------------------
# Product: Laurel Large Shoulder Bag
# Item ID: CBG98
# Variation ID: IMTN2
# Product URL: https://www.coach.com/products/laurel-large-shoulder-bag/CBG98.html?frp=CBG98+IMTN2
# Comparable Value: $498
# Sale Price: $229   - Sales Price    - Original Price
# Discount: 54%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: West Pack In Signature Canvas With Varsity Stripe
# Item ID: CV923
# Variation ID: QBOH0
# Product URL: https://www.coach.com/products/west-pack-in-signature-canvas-with-varsity-stripe/CV923.html?frp=CV923+QBOH0
# Comparable Value: $378
# Sale Price: $119   - Sales Price    - Original Price
# Discount: 69%
# Additional Discount:
# Description: Canvas,Leather,Slingback,Stripe,Adjustable,Casual,Black,Front View
# --------------------------------------------------
# Product: Teri Shoulder Bag
# Item ID: CBI17
# Variation ID: IMBLK
# Product URL: https://www.coach.com/products/teri-shoulder-bag/CBI17.html?frp=CBI17+IMBLK
# Comparable Value:
# Sale Price: $140
# Discount:
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Teri Mini Crossbody Bag With Leopard Print
# Item ID: CBG65
# Variation ID: IMXAC
# Product URL: https://www.coach.com/products/teri-mini-crossbody-bag-with-leopard-print/CBG65.html?frp=CBG65+IMXAC
# Comparable Value:
# Sale Price: $179
# Discount:
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Hadley Mini Crossbody Bag
# Item ID: CAL60
# Variation ID: IMV2R
# Product URL: https://www.coach.com/products/hadley-mini-crossbody-bag/CAL60.html?frp=CAL60+IMV2R
# Comparable Value: $225
# Sale Price: $149   - Sales Price    - Original Price
# Discount: 34%
# ...
# Comparable Value:
# Sale Price: $219
# Discount:
# Additional Discount:
# Description:
# --------------------------------------------------
# Product: Chain Tabby Shoulder Bag
# Item ID: CY919
# Variation ID: B4%2FHA
# Product URL: https://www.coach.com/products/chain-tabby-shoulder-bag/CY919.html?frp=CY919+B4%2FHA
# Comparable Value:
# Sale Price: $495
# Discount:
# Additional Discount:
# Description:
# --------------------------------------------------
# Product: Cargo Tote Bag With Sketch Print
# Item ID: CAM73
# Variation ID: B4%2FNP
# Product URL: https://www.coach.com/products/cargo-tote-bag-with-sketch-print/CAM73.html?frp=CAM73+B4%2FNP
# Comparable Value: $295
# Sale Price: $206.50
# Discount: 30%
# Additional Discount:
# Description:
# --------------------------------------------------
# Product: Coach X Peanuts Court Backpack In Signature Canvas With Snoopy Print
# Item ID: CBM25
# Variation ID: IMY3O
# Product URL: https://www.coach.com/products/coach-x-peanuts-court-backpack-in-signature-canvas-with-snoopy-print/CBM25.html?frp=CBM25+IMY3O
# Comparable Value: $498
# Sale Price: $199.20
# Discount: 60%
# Additional Discount:
# Description:
# --------------------------------------------------
# Product: Warren Mini Belt Bag With Surf Print
# Item ID: CBI28
# Variation ID: QBCAH
# Product URL: https://www.coach.com/products/warren-mini-belt-bag-with-surf-print/CBI28.html?frp=CBI28+QBCAH
# Comparable Value: $378
# Sale Price: $109
# Discount: 71%
# Additional Discount:
# Description:
# --------------------------------------------------
# Product: Soft Tabby Shoulder Bag
# Item ID: CAM98
# Variation ID: B4%2FBK
# Product URL: https://www.coach.com/products/soft-tabby-shoulder-bag/CAM98.html?frp=CAM98+B4%2FBK
# Comparable Value:
# Sale Price: $395
# Discount:
# Additional Discount:
# Description:
# --------------------------------------------------
# Product: Tabby Shoulder Bag 26 With Patchwork Quilting
# Item ID: CAM91
# Variation ID: B4%2FEI
# Product URL: https://www.coach.com/products/tabby-shoulder-bag-26-with-patchwork-quilting/CAM91.html?frp=CAM91+B4%2FEI
# Comparable Value:
# Sale Price: $650
# Discount:
# Additional Discount:
# Description:
# --------------------------------------------------
# Product: Cargo Tote Bag 20
# Item ID: CZ098
# Variation ID: LHBLK
# Product URL: https://www.coach.com/products/cargo-tote-bag-20/CZ098.html?frp=CZ098+LHBLK
# Comparable Value:
# Sale Price: $150
# Discount:
# Additional Discount:
# Description:
# --------------------------------------------------
# Product: Warren Belt Bag In Signature Jacquard
# Item ID: CT815
# Variation ID: SVS8S
# Product URL: https://www.coach.com/products/warren-belt-bag-in-signature-jacquard/CT815.html?frp=CT815+SVS8S
# Comparable Value: $350
# Sale Price: $105
# Discount: 70%
# Additional Discount:
# Description: Recycled Polyester,Leather,Cotton,Belt Bag,Color Block,Casual,Brown,Front View
# --------------------------------------------------
# Product: Dylan Tote Bag In Colorblock Signature Canvas
# Item ID: CP050
# Variation ID: QBO3I
# Product URL: https://www.coach.com/products/dylan-tote-bag-in-colorblock-signature-canvas/CP050.html?frp=CP050+QBO3I
# Comparable Value: $428
# Sale Price: $129
# Discount: 70%
# Additional Discount:
# Description: Calfskin Leather,Canvas,Tote,Logo,Word Embellishment,Casual,Black,Front View
# --------------------------------------------------
# Product: West Pack With Baseball Print
# Item ID: CAX48
# Variation ID: QBRHY
# Product URL: https://www.coach.com/products/west-pack-with-baseball-print/CAX48.html?frp=CAX48+QBRHY
# Comparable Value: $398
# Sale Price: $119.40
# Discount: 70%
# Additional Discount:
# Description: Leather,Slingback,Embossed,Logo,Casual,Navy,Front View
# --------------------------------------------------
# Product: Coach X Peanuts Teri Shoulder Bag With Lucy
# Item ID: CBM32
# Variation ID: IMBCV
# Product URL: https://www.coach.com/products/coach-x-peanuts-teri-shoulder-bag-with-lucy/CBM32.html?frp=CBM32+IMBCV
# Comparable Value:
# Sale Price: $219
# Discount:
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Finn Crossbody Bag
# Item ID: CBI75
# Variation ID: QBXR9
# Product URL: https://www.coach.com/products/finn-crossbody-bag/CBI75.html?frp=CBI75+QBXR9
# Comparable Value: $398
# Sale Price: $119
# Discount: 70%
# Additional Discount:
# Description: Blue,Front View
# --------------------------------------------------
# Product: Sullivan Pack In Signature Canvas With Patches
# Item ID: CY819
# Variation ID: QBTAM
# Product URL: https://www.coach.com/products/sullivan-pack-in-signature-canvas-with-patches/CY819.html?frp=CY819+QBTAM
# Comparable Value: $398
# Sale Price: $149
# Discount: 63%
# Additional Discount:
# Description: Canvas,Leather,Slingback,Applique,Color Block,Adjustable,Casual,Brown,Front View
# --------------------------------------------------
# Product: District Crossbody Bag In Signature Canvas
# Item ID: CV761
# Variation ID: QBMI5
# Product URL: https://www.coach.com/products/district-crossbody-bag-in-signature-canvas/CV761.html?frp=CV761+QBMI5
# Comparable Value: $378
# Sale Price: $113.40
# Discount: 70%
# Additional Discount:
# Description: Crossbody,Color Block,Casual,Multi Color,Front View
# --------------------------------------------------
# Product: Sullivan Pack In Signature Canvas
# Item ID: CZ397
# Variation ID: QBNRX
# Product URL: https://www.coach.com/products/sullivan-pack-in-signature-canvas/CZ397.html?frp=CZ397+QBNRX
# Comparable Value: $350
# Sale Price: $149
# Discount: 57%
# Additional Discount:
# Description: Canvas,Leather,Slingback,Logo,Adjustable,Casual,Brown,Front View
# --------------------------------------------------
# Product: Warner Crossbody Bag
# Item ID: CW218
# Variation ID: SV%2FBK
# Product URL: https://www.coach.com/products/warner-crossbody-bag/CW218.html?frp=CW218+SV%2FBK
# Comparable Value: $398
# Sale Price: $129
# Discount: 68%
# Additional Discount:
# Description: Crossbody,Casual,Black,Front View
# --------------------------------------------------
# Product: Wyatt Crossbody Bag
# Item ID: CM113
# Variation ID: QB%2FBK
# Product URL: https://www.coach.com/products/wyatt-crossbody-bag/CM113.html?frp=CM113+QB%2FBK
# Comparable Value: $328
# Sale Price: $129
# Discount: 61%
# Additional Discount:
# Description: Leather,Crossbody,Casual,,Front View
# --------------------------------------------------
# Product: Racer Pack
# Item ID: CU111
# Variation ID: QB%2FBK
# Product URL: https://www.coach.com/products/racer-pack/CU111.html?frp=CU111+QB%2FBK
# Comparable Value: $398
# Sale Price: $119
# Discount: 70%
# Additional Discount:
# Description: Slingback,Logo,Metal,Pen Holder,Casual,Black,Front View
# --------------------------------------------------
# Product: West Backpack With Baseball Print
# Item ID: CAX47
# Variation ID: QBRHY
# Product URL: https://www.coach.com/products/west-backpack-with-baseball-print/CAX47.html?frp=CAX47+QBRHY
# Comparable Value: $598
# Sale Price: $179.40
# Discount: 70%
# Additional Discount:
# Description: Leather,Backpack,Color Block,Logo,Embossed,Casual,Navy,Front View
# --------------------------------------------------
# Product: Finn Crossbody Bag
# Item ID: CAJ70
# Variation ID: QBCHK
# Product URL: https://www.coach.com/products/finn-crossbody-bag/CAJ70.html?frp=CAJ70+QBCHK
# Comparable Value: $398
# Sale Price: $119
# Discount: 70%
# Additional Discount:
# Description: Leather,Crossbody,Logo,Embossed,Casual,White,Front View
# --------------------------------------------------
# Product: Warner Backpack
# Item ID: CW210
# Variation ID: SVMPL
# Product URL: https://www.coach.com/products/warner-backpack/CW210.html?frp=CW210+SVMPL
# Comparable Value: $698
# Sale Price: $179
# Discount: 74%
# Additional Discount:
# Description: Backpack,Casual,Brown,Front View
# --------------------------------------------------
# Product: League Belt Bag In Signature Canvas Jacquard
# Item ID: CU008
# Variation ID: ARY
# Product URL: https://www.coach.com/products/league-belt-bag-in-signature-canvas-jacquard/CU008.html?frp=CU008+ARY
# Comparable Value: $350
# Sale Price: $140
# Discount: 60%
# Additional Discount:
# Description: Calfskin Leather,Canvas,Belt Bag,Leather Embellishment,Adjustable,Casual,Olive,Front View
# --------------------------------------------------
# Product: Track Pack In Signature Canvas
# Item ID: CX880
# Variation ID: QBNRX
# Product URL: https://www.coach.com/products/track-pack-in-signature-canvas/CX880.html?frp=CX880+QBNRX
# Comparable Value: $398
# Sale Price: $119.40
# Discount: 70%
# Additional Discount:
# Description: Beige,Front View
# --------------------------------------------------
# Product: Turnlock Sling Pack
# Item ID: CAJ72
# Variation ID: QB%2FBK
# Product URL: https://www.coach.com/products/turnlock-sling-pack/CAJ72.html?frp=CAJ72+QB%2FBK
# Comparable Value: $378
# Sale Price: $129
# Discount: 66%
# Additional Discount:
# Description: Calfskin Leather,Slingback,Adjustable,Gunmetal,Casual,Black,Front View
# --------------------------------------------------
# Product: Racer Messenger Bag
# Item ID: CU110
# Variation ID: QB%2FBK
# Product URL: https://www.coach.com/products/racer-messenger-bag/CU110.html?frp=CU110+QB%2FBK
# Comparable Value: $498
# Sale Price: $169
# Discount: 66%
# Additional Discount:
# Description: Messenger Bag,Metal,Logo,Pen Holder,Casual,Black,Front View
# --------------------------------------------------
# Product: Carmen Mini Crossbody Bag With Lemon Print
# Item ID: CAL00
# Variation ID: SVXUC
# Product URL: https://www.coach.com/products/carmen-mini-crossbody-bag-with-lemon-print/CAL00.html?frp=CAL00+SVXUC
# Comparable Value: $298
# Sale Price: $89.40
# Discount: 70%
# Additional Discount:
# Description: Canvas,Leather,Crossbody,Chain Detail,Piping,Metal,Color Block,Logo,Silv...,Yellow,Front View
# --------------------------------------------------
# Product: Racer Pack
# Item ID: CBI69
# Variation ID: QBPOL
# Product URL: https://www.coach.com/products/racer-pack/CBI69.html?frp=CBI69+QBPOL
# Comparable Value: $398
# Sale Price: $119
# Discount: 70%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Racer Pack In Signature
# Item ID: CT712
# Variation ID: QBMI5
# Product URL: https://www.coach.com/products/racer-pack-in-signature/CT712.html?frp=CT712+QBMI5
# Comparable Value: $398
# Sale Price: $119
# Discount: 70%
# Additional Discount:
# Description: Slingback,Pen Holder,Casual,Black,Front View
# --------------------------------------------------
# Product: Mollie Tote Bag 25 With Heart Bolt Print
# Item ID: CW435
# Variation ID: SVA47
# Product URL: https://www.coach.com/products/mollie-tote-bag-25-with-heart-bolt-print/CW435.html?frp=CW435+SVA47
# Comparable Value: $378
# Sale Price: $113.40
# Discount: 70%
# Additional Discount:
# Description: Leather,Crossbody,Logo,Metal,Casual,Black,Front View
# --------------------------------------------------
# Product: Teri Mini Crossbody Bag With Lemon Print
# Item ID: CAL21
# Variation ID: SVXUC
# Product URL: https://www.coach.com/products/teri-mini-crossbody-bag-with-lemon-print/CAL21.html?frp=CAL21+SVXUC
# Comparable Value: $298
# Sale Price: $89.40
# Discount: 70%
# Additional Discount:
# Description: Crossbody,Color Block,Metal,Chain Detail,Logo,Silver Metal,Casual,Yellow,Front View
# --------------------------------------------------
# Product: Mini Rowan Crossbody Bag With Lemon Print
# Item ID: CAL19
# Variation ID: SVXUC
# Product URL: https://www.coach.com/products/mini-rowan-crossbody-bag-with-lemon-print/CAL19.html?frp=CAL19+SVXUC
# Comparable Value: $328
# Sale Price: $98.40
# Discount: 70%
# Additional Discount:
# Description: Barrel Bag,Piping,Color Block,Logo,Silver Metal,Casual,Yellow,Front View
# --------------------------------------------------
# Product: Turnlock Sling Pack In Signature Canvas
# Item ID: CAJ92
# Variation ID: QBMI5
# Product URL: https://www.coach.com/products/turnlock-sling-pack-in-signature-canvas/CAJ92.html?frp=CAJ92+QBMI5
# Comparable Value: $378
# Sale Price: $129
# Discount: 66%
# Additional Discount:
# Description: Canvas,Calfskin Leather,Slingback,Adjustable,Gunmetal,Casual,Black,Front View
# --------------------------------------------------
# Product: Mini Klare Crossbody Bag With Lemon Print
# Item ID: CAN24
# Variation ID: IMXUC
# Product URL: https://www.coach.com/products/mini-klare-crossbody-bag-with-lemon-print/CAN24.html?frp=CAN24+IMXUC
# Comparable Value: $328
# Sale Price: $98.40
# Discount: 70%
# Additional Discount:
# Description: Leather,Crossbody,Color Block,Metal,Logo,Gold Metal,Day Party,Cream,Front View
# --------------------------------------------------
# Product: Quinn Bag
# Item ID: CBR15
# Variation ID: SV%2FII
# Product URL: https://www.coach.com/products/quinn-bag/CBR15.html?frp=CBR15+SV%2FII
# Comparable Value: $450
# Sale Price: $135
# Discount: 70%
# Additional Discount:
# Description: Purple,Front View
# --------------------------------------------------
# Product: Slim Crossbody Bag With Floral Print
# Item ID: CAQ27
# Variation ID: SVCAH
# Product URL: https://www.coach.com/products/slim-crossbody-bag-with-floral-print/CAQ27.html?frp=CAQ27+SVCAH
# Comparable Value: $298
# Sale Price: $89.40
# Discount: 70%
# Additional Discount:
# Description: Leather,Crossbody,Metal,Logo,Adjustable,Casual,White,Front View
# --------------------------------------------------
# Product: Turnlock Sling Pack
# Item ID: CBI62
# Variation ID: QBTN2
# Product URL: https://www.coach.com/products/turnlock-sling-pack/CBI62.html?frp=CBI62+QBTN2
# Comparable Value: $378
# Sale Price: $129
# Discount: 66%
# Additional Discount:
# Description: Front View
# --------------------------------------------------
# Product: Mini Rowan Crossbody Bag With Floral Print
# Item ID: CBM69
# Variation ID: IMY2K
# Product URL: https://www.coach.com/products/mini-rowan-crossbody-bag-with-floral-print/CBM69.html?frp=CBM69+IMY2K
# Comparable Value: $328
# Sale Price: $98.40
# Discount: 70%
# Additional Discount:
# Description: Multi Color,Front View
# --------------------------------------------------
# Product: Teri Shoulder Bag With Heart Bolt Print
# Item ID: CY346
# Variation ID: SVA47
# Product URL: https://www.coach.com/products/teri-shoulder-bag-with-heart-bolt-print/CY346.html?frp=CY346+SVA47
# Comparable Value: $350
# Sale Price: $105
# Discount: 70%
# Additional Discount:
# Description: Leather,Canvas,Shoulder Bag,Logo,Metal,Casual,Black,Front View
# --------------------------------------------------
# Product: Mini Jamie Camera Bag With Floral Print
# Item ID: CAQ38
# Variation ID: SVCAH
# Product URL: https://www.coach.com/products/mini-jamie-camera-bag-with-floral-print/CAQ38.html?frp=CAQ38+SVCAH
# Comparable Value: $328
# Sale Price: $98.40
# Discount: 70%
# Additional Discount:
# Description: Leather,Camera Bag,Color Block,Metal,Logo,Adjustable,Casual,White,Front View
# --------------------------------------------------
# Product: Mini Klare Crossbody Bag In Colorblock With Floral Print
# Item ID: CBM62
# Variation ID: IMY2K
# Product URL: https://www.coach.com/products/mini-klare-crossbody-bag-in-colorblock-with-floral-print/CBM62.html?frp=CBM62+IMY2K
# Comparable Value: $378
# Sale Price: $113.40
# Discount: 70%
# Additional Discount:
# Description: Lavender,Front View
# --------------------------------------------------
# Product: Jamie Camera Bag With Strawberry Graphic
# Item ID: CBA65
# Variation ID: IMCAH
# Product URL: https://www.coach.com/products/jamie-camera-bag-with-strawberry-graphic/CBA65.html?frp=CBA65+IMCAH
# Comparable Value: $350
# Sale Price: $105
# Discount: 70%
# Additional Discount:
# Description: Leather,Camera Bag,Gold Metal,Casual,Cream,Front View
# --------------------------------------------------
# Product: District Crossbody Bag In Signature Canvas
# Item ID: CH078
# Variation ID: QBMI5
# Product URL: https://www.coach.com/products/district-crossbody-bag-in-signature-canvas/CH078.html?frp=CH078+QBMI5
# Comparable Value: $378
# Sale Price: $113.40
# Discount: 70%
# Additional Discount:
# Description: Canvas,Leather,Crossbody,PVC,Color Block,Logo,Casual,Multi Color,Front View
# --------------------------------------------------
# Product: Racer Backpack
# Item ID: CU112
# Variation ID: QB%2FBK
# Product URL: https://www.coach.com/products/racer-backpack/CU112.html?frp=CU112+QB%2FBK
# Comparable Value: $650
# Sale Price: $195
# Discount: 70%
# Additional Discount:
# Description: Backpack,Logo,Metal,Pen Holder,Casual,Black,Front View
# --------------------------------------------------

# %% [markdown]
# # New Section
